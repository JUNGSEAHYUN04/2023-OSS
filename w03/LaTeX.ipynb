# %%
# 실습 준비 — 03주차 1차원 데이터 정리 리마인드 · 퀴즈 · LaTeX
# 이 셀을 먼저 한 번 실행하세요. 데이터가 없으면 아래 셀들이 전부 실패합니다.
import os, pathlib, urllib.request

BASE = "https://raw.githubusercontent.com/aprilslab/statistics-lab/main/data/"
FILES = []

pathlib.Path("data").mkdir(exist_ok=True)
for name in FILES:
    for dest in (pathlib.Path(name), pathlib.Path("data") / name):
        if not dest.exists():
            urllib.request.urlretrieve(BASE + name, dest)

# '../data/x.csv' 로 읽는 노트북 대응 — 상위 폴더에도 같은 data/ 를 걸어둔다.
# 절대경로(/data)로 박으면 cwd 가 /content 가 아닐 때 깨지므로 상대경로로 건다.
try:
    parent = pathlib.Path("..") / "data"
    if not parent.exists():
        os.symlink(pathlib.Path("data").resolve(), parent)
except OSError:
    pass

print("준비 완료:", ", ".join(FILES) if FILES else "(내려받을 데이터 없음)")
# Out:
# 준비 완료: (내려받을 데이터 없음)

# %% [markdown]
# # LaTeX
#
# 문서 조판 프로그래밍 언어로, 논문이나 출판물 등의 특수 형식 문서를 작성하는 데 쓰이는 시스템이다. 자연과학이나 인문과학 중 수식, 그래프, 다이어그램을 많이 그리는 학자들에게 유용한 문서 저작 도구이다. 미국의 컴퓨터 과학자인 레슬리 램포트가 1984년 발표하였다. 발음은 후술되겠지만 라텍이 보편적으로 권장된다.

# %%
from IPython.display import display, Math

display(Math(r'a + b = c'))
# Out:
# $\displaystyle a + b = c$

# %% [markdown]
# ## 수식을 쓰는 세 가지 방법
#
# 같은 LaTeX 을 어디에 어떻게 감싸느냐에 따라 쓰는 법이 다르다. **안에 들어가는 LaTeX 본체는 셋 다 같다.**
#
# | 방법 | 어디에 쓰나 | 화면에서 |
# |---|---|---|
# | `$ 수식 $` | 마크다운 셀 · 문장 속에 섞어 | 글줄 안에 그대로 |
# | `$$ 수식 $$` | 마크다운 셀 · 문단으로 떼어 | 가운데 정렬, 크게 |
# | `display(Math(r'수식'))` | 코드 셀 · 실행 결과로 | `Out[n]` 으로 나옴 |
#
# 아래 두 셀이 같은 수식을 서로 다른 방법으로 낸다. **이 셀을 더블클릭하면 마크다운 원본을 볼 수 있다.**
#
# 문장 속에 넣으면 이렇게 된다 — 평균은 $\bar{x}$ 로 적는다.
#
# 문단으로 떼면 이렇게 된다.
#
# $$
# \bar{x} = \frac{1}{n}\sum_{i=1}^{n} x_i
# $$
#
# ### r'' 을 빼면 깨진다
#
# 코드 셀에서 `Math()` 를 쓸 때는 따옴표 앞에 `r` 을 붙인다. 파이썬이 따옴표 안의 백슬래시를 먼저 해석하기 때문이다.
#
# | 쓴 것 | raw string 일 때 | 그냥 따옴표일 때 |
# |---|---|---|
# | `\frac` | `\frac` 그대로 | 폼피드 문자 + `rac` |
# | `\nu` | `\nu` 그대로 (그리스 문자 뉴) | 줄바꿈 + `u` |
# | `\times` | `\times` 그대로 | 탭 + `imes` |
#
# 마크다운 셀의 `$…$` 에는 이 문제가 없다. 파이썬 문자열이 아니기 때문이다.

# %%
# 위 마크다운 셀과 같은 수식을 코드로 낸다
display(Math(r'\bar{x} = \frac{1}{n}\sum_{i=1}^{n} x_i'))

# r 을 빼면 어떻게 되는지 직접 확인해 보자
display(Math(r'\frac{1}{n}'))   # 분수가 나온다
display(Math('\frac{1}{n}'))    # 깨지거나 엉뚱한 것이 나온다
# Out:
# $\displaystyle \bar{x} = \frac{1}{n}\sum_{i=1}^{n} x_i$
# $\displaystyle \frac{1}{n}$
# $\displaystyle rac{1}{n}$

# %% [markdown]
# ## 02. 1차원 데이터 정리

# %% [markdown]
# ### 평균값 ( mean, 기댓값, E(X), $\mu$ )
# $$
# \bar{x} = \frac{1}{n}{\sum_{i=1}^{n} x_i}
# $$
#
# * `\bar{x}` -> $\bar{x}$
# * `\frac{1}{n}` -> $\frac{1}{n}$
# * `x_i` -> x_i
# * `\sum_{i=1}^{n} x_i` -> $\sum_{i=1}^{n} x_i$

# %%
display(Math(r'\bar{x} = \frac{1}{n}\sum_{i=1}^{n}x_i'))
# Out:
# $\displaystyle \bar{x} = \frac{1}{n}\sum_{i=1}^{n}x_i$

# %% [markdown]
# ### 분산
#
# $$
# {S}^2 = \frac{1}{n}{\sum_{i=1}^{n} ({x_i - \bar{x}})^2}
# $$
#
# * `S^2` -> $S^2$
# * `({x_i - \bar{x}})^2` -> $({x_i - \bar{x}})^2$

# %%
display(Math(r'S^2 = \frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})^2'))
# Out:
# $\displaystyle S^2 = \frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})^2$

# %% [markdown]
# ### 표준편차
# <center>
# $
# S^2 = \sqrt{S^2} = \sqrt{\displaystyle \frac{1}{n} \sum_{i=1}^n (x_i - \bar{x})^2}
# $
# </center>
#
# * `\sqrt{S^2}` -> $\sqrt{S^2}$

# %%
display(Math(r'S = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})^2}'))
# Out:
# $\displaystyle S = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})^2}$

# %% [markdown]
# ### 범위 (range)
#
# $$
# {Rg} = {x_{\max} - x_{\min}}
# $$
#
# * `x_{\max}` -> $x_{\max}$
# * `x_{\min}` -> $x_{\min}$

# %%
display(Math(r'R_g = x_{\max} - x_{\min}'))
# Out:
# $\displaystyle R_g = x_{\max} - x_{\min}$

# %% [markdown]
# ### 표준화 (standardization)
#
# $$
# {z_i} = \frac{{x_i - \bar{x}}}{{S}}
# $$

# %%
display(Math(r'z_i = \frac{x_i-\bar{x}}{S}'))
# Out:
# $\displaystyle z_i = \frac{x_i-\bar{x}}{S}$

# %% [markdown]
# ### 편차값
#
# $$
# {z_i} = { 50 + 10 \times \frac{{x_i} - \bar{x}}{S} }
# $$

# %%
display(Math(r'z_i = 50 + 10 \times \frac{x_i-\bar{x}}{S}'))
# Out:
# $\displaystyle z_i = 50 + 10 \times \frac{x_i-\bar{x}}{S}$

# %% [markdown]
# ## 03. 2차원 데이터 정리

# %% [markdown]
# ### 공분산
#
# $$
# S_{xy} = \frac{1}{n}{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}
# $$

# %%
display(Math(r'S_{xy} = \frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y})'))
# Out:
# $\displaystyle S_{xy} = \frac{1}{n}\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y})$

# %% [markdown]
# ### 상관계수
#
# $$
# r_{xy} = \frac{1}{n}\sum_{i=1}^{n}(\frac{x_i - \bar{x}}{S_x})(\frac{y_i - \bar{y}}{S_y}) = \frac{S_{xy}}{{S_x}{S_y}}
# $$

# %%
display(Math(r'r_{xy} = \frac{1}{n}\sum_{i=1}^{n}\left(\frac{x_i-\bar{x}}{S_x}\right)\left(\frac{y_i-\bar{y}}{S_y}\right) = \frac{S_{xy}}{S_xS_y}'))
# Out:
# $\displaystyle r_{xy} = \frac{1}{n}\sum_{i=1}^{n}\left(\frac{x_i-\bar{x}}{S_x}\right)\left(\frac{y_i-\bar{y}}{S_y}\right) = \frac{S_{xy}}{S_xS_y}$

# %% [markdown]
# ## 04. 추측통계의 기본

# %% [markdown]
# $$
# P(X=1) = \frac16
# $$
#
# $$
# P((X=1)\cup(X=3)\cup(X=5)) = P(X=1) + P(X=3) + P(X=5) = \frac{1}{6}+\frac{1}{6}+\frac{1}{6} = \frac{1}{2}
# $$
#
# * `A \cup B`-> $A \cup B$

# %%
display(Math(r'P(X=1) = \frac{1}{6}'))
display(Math(r'P((X=1)\cup(X=3)\cup(X=5)) = P(X=1)+P(X=3)+P(X=5) = \frac{1}{6}+\frac{1}{6}+\frac{1}{6} = \frac{1}{2}'))
# Out:
# $\displaystyle P(X=1) = \frac{1}{6}$
# $\displaystyle P((X=1)\cup(X=3)\cup(X=5)) = P(X=1)+P(X=3)+P(X=5) = \frac{1}{6}+\frac{1}{6}+\frac{1}{6} = \frac{1}{2}$

# %% [markdown]
# ## 05. 이산형 확률변수

# %% [markdown]
# $$
# f(x) = \left\{
# \begin{array}{ll}
# \frac{x}{21} && (x \in \{1,2,3,4,5,6\}) \\
# 0 && (otherwise)
# \end{array}
# \right.
# $$
#
# * `\left \{ \right.` (left 옆에 있는거 크기 자동 조절: 큰 중괄호 만들기) -> $\left \{ \right.$
# * `x \in \{1,2,3,4,5,6\}` -> $x \in \{1,2,3,4,5,6\}$
# * `\begin {array}{ll}` -> 배열 시작, ll=왼쪽 정렬 두 열
# * `\end {array}` -> 배열 종료

# %%
display(Math(r'f(x) = \begin{cases} \frac{x^2}{10} & (x \in \{1,2,3,4,5,6\}) \\ 0 & (\text{otherwise}) \end{cases}'))
# Out:
# $\displaystyle f(x) = \begin{cases} \frac{x^2}{10} & (x \in \{1,2,3,4,5,6\}) \\ 0 & (\text{otherwise}) \end{cases}$

# %% [markdown]
# ### 확률의 성질
# $$
# f(x_k) \ge 0
# $$
# $$
# \sum_k f(x_k) = 1
# $$
#
# * `\ge` -> $\ge$
# * `\le`-> $\le$

# %%
display(Math(r'\begin{aligned} f(x_k) &\geq 0 \\ \sum_k f(x_k) &= 1 \end{aligned}'))
# Out:
# $\displaystyle \begin{aligned} f(x_k) &\geq 0 \\ \sum_k f(x_k) &= 1 \end{aligned}$

# %% [markdown]
# ### 누적분포함수 (CDF)
# $$F(x) = P(X \le x) = \sum_{x_k \le x}f(x_k)$$

# %%
display(Math(r'F(x)=P(X\leq x)=\sum_{x_k\leq x}f(x_k)'))
# Out:
# $\displaystyle F(x)=P(X\leq x)=\sum_{x_k\leq x}f(x_k)$

# %% [markdown]
# ### 기댓값
# $$
# E(X) = \sum_k x_k f(x_k)
# $$

# %%
display(Math(r'E(X)=\sum_k x_k f(x_k)'))
# Out:
# $\displaystyle E(X)=\sum_k x_k f(x_k)$

# %% [markdown]
# ### 분산
# $$
# V(X) = \sum_k (x_k - \mu)^2 f(x_k)
# $$

# %%
display(Math(r'V(X)=\sum_k(x_k-\mu)^2f(x_k)'))
# Out:
# $\displaystyle V(X)=\sum_k(x_k-\mu)^2f(x_k)$

# %% [markdown]
# ### 결합확률함수
# $$
# P(X=x,Y=y) = f_{XY}(x,y)
# $$

# %%
display(Math(r'P(X=x,Y=y)=f_{XY}(x,y)'))
# Out:
# $\displaystyle P(X=x,Y=y)=f_{XY}(x,y)$

# %% [markdown]
# ### 주변확률함수
# $$
# f_X(x) = \sum_k f_{XY}(x,y_k)
# $$

# %%
display(Math(r'f_X(x)=\sum_k f_{XY}(x,y_k)'))
# Out:
# $\displaystyle f_X(x)=\sum_k f_{XY}(x,y_k)$

# %% [markdown]
# ### 기댓값
# $$\mu_X = E(X) = \sum_i \sum_j x_i f_{XY} (x_i, y_j)$$
# * `\mu`-> $\mu$

# %%
display(Math(r'\mu_X=E(X)=\sum_i\sum_j x_i f_{XY}(x_i,y_j)'))
# Out:
# $\displaystyle \mu_X=E(X)=\sum_i\sum_j x_i f_{XY}(x_i,y_j)$

# %% [markdown]
# ### 분산
#
# $$
# \sigma^2_X = V(X) = \sum_i \sum_j (x_i - \mu_X)^2 f_{XY}(x_i, y_j)
# $$
#
# * `\sigma`-> $\sigma$

# %%
display(Math(r'\sigma_X^2=V(X)=\sum_i\sum_j(x_i-\mu_X)^2f_{XY}(x_i,y_j)'))
# Out:
# $\displaystyle \sigma_X^2=V(X)=\sum_i\sum_j(x_i-\mu_X)^2f_{XY}(x_i,y_j)$

# %% [markdown]
# ### 공분산
# $$
# \sigma_{XY} = Cov(X,Y) = \sum_i \sum_j (x_i - \mu_X)(y_j - \mu_Y)f_{XY}(x_i,y_i)
# $$

# %%
display(Math(r'\sigma_{XY}=\operatorname{Cov}(X,Y)=\sum_i\sum_j(x_i-\mu_X)(y_j-\mu_Y)f_{XY}(x_i,y_j)'))
# Out:
# $\displaystyle \sigma_{XY}=\operatorname{Cov}(X,Y)=\sum_i\sum_j(x_i-\mu_X)(y_j-\mu_Y)f_{XY}(x_i,y_j)$

# %% [markdown]
# ## 06. 대표적인 이산형 확률분포

# %% [markdown]
# ### 베르누이 분포
# 확률질량함수
# $$
# f(x) = \left\{
# \begin{array}{ll}
# p^x (1-p)^{1-x}, & (x \in \{0, 1\}) \\
# 0 & (otherwise)
# \end{array}
# \right.
# $$

# %%
display(Math(r'f(x)=\begin{cases}p^x(1-p)^{1-x} & (x\in\{0,1\})\\0 & (\text{otherwise})\end{cases}'))
# Out:
# $\displaystyle f(x)=\begin{cases}p^x(1-p)^{1-x} & (x\in\{0,1\})\\0 & (\text{otherwise})\end{cases}$

# %% [markdown]
# ### 이항분포
# 확률질량함수
# $$
# f(x) = \left\{
# \begin{array}{ll}
# _nC_x(1-p)^{(n-x)}, & (x \in \{0, 1, ..., n\}) \\
# 0 & (otherwise)
# \end{array}
# \right.
# $$

# %%
display(Math(r'f(x)=\begin{cases}\binom{n}{x}p^x(1-p)^{n-x} & (x\in\{0,1,\ldots,n\})\\0 & (\text{otherwise})\end{cases}'))
# Out:
# $\displaystyle f(x)=\begin{cases}\binom{n}{x}p^x(1-p)^{n-x} & (x\in\{0,1,\ldots,n\})\\0 & (\text{otherwise})\end{cases}$

# %% [markdown]
# ### 기하분포
# 확률질량함수
# $$
# f(x) = \left\{
# \begin{array}{ll}
# (1-p)^{(x-1)}p, & (x \in \{1,2,3, ...\}) \\
# 0 & (otherwise)
# \end{array}
# \right.
# $$

# %%
display(Math(r'f(x)=\begin{cases}(1-p)^{x-1}p & (x\in\{1,2,3,\ldots\})\\0 & (\text{otherwise})\end{cases}'))
# Out:
# $\displaystyle f(x)=\begin{cases}(1-p)^{x-1}p & (x\in\{1,2,3,\ldots\})\\0 & (\text{otherwise})\end{cases}$

# %% [markdown]
# ### 포아송 분포
# 확률질량함수
# $$
# f(x) = \left\{
# \begin{array}{ll}
# \frac{\lambda^x}{x!} \cdot e^{-\lambda} \, & (x \in \{0,1,2, ...\}) \\
# 0 & (otherwise)
# \end{array}
# \right.
# $$

# %%
display(Math(r'f(x)=\begin{cases}\frac{\lambda^x}{x!}e^{-\lambda} & (x\in\{0,1,2,\ldots\})\\0 & (\text{otherwise})\end{cases}'))
# Out:
# $\displaystyle f(x)=\begin{cases}\frac{\lambda^x}{x!}e^{-\lambda} & (x\in\{0,1,2,\ldots\})\\0 & (\text{otherwise})\end{cases}$

# %% [markdown]
# ## 07. 연속형 확률변수

# %% [markdown]
# ### 확률밀도함수
#
# $$
# P(x_0 \le X \le x_1) = \int_{x_0}^{x_1} f(x) \, dx
# $$
# * `\,` -> 빈공간 (space)

# %%
display(Math(r'P(x_0\leq X\leq x_1)=\int_{x_0}^{x_1}f(x)\,dx'))
# Out:
# $\displaystyle P(x_0\leq X\leq x_1)=\int_{x_0}^{x_1}f(x)\,dx$

# %% [markdown]
# ### 누적분포함수
# $$
# F(x) = P(x \le x) = \int_{-\infty}^{\infty} f(x)dx
# $$
# * `\infty` -> $\infty$

# %%
display(Math(r'F(x)=P(X\leq x)=\int_{-\infty}^{\infty}f(x)\,dx'))
# Out:
# $\displaystyle F(x)=P(X\leq x)=\int_{-\infty}^{\infty}f(x)\,dx$

# %% [markdown]
# ### 08. 대표적인 연속형 확률분포

# %% [markdown]
# ### 정규분포
# $$N(\mu,\sigma^2)$$
#
# * $P(X \ge x) = \alpha$를 만족하는 $x$
# * `\alpha`-> $\alpha$

# %%
display(Math(r'N(\mu,\sigma^2)'))
# Out:
# $\displaystyle N(\mu,\sigma^2)$

# %% [markdown]
# ### 지수분포
# $$
# Ex(\lambda)
# $$
#
# * `\lambda`-> $\lambda$

# %%
display(Math(r'Ex(\lambda)'))
# Out:
# $\displaystyle Ex(\lambda)$

# %% [markdown]
# ### 카이제곱분포
# $$\chi^2(n)$$

# %%
display(Math(r'\chi^2(n)'))
# Out:
# $\displaystyle \chi^2(n)$

# %% [markdown]
# ### t분포
# $$
# t(n)
# $$

# %%
display(Math(r't(n)'))
# Out:
# $\displaystyle t(n)$

# %% [markdown]
# ### F분포
# $$F(n_1, n_2)$$

# %%
display(Math(r''))
# Out:
# $\displaystyle F(n_1,n_2)$
